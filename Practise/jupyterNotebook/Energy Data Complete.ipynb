# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import scipy as sp

# %%
Energy = pd.read_csv('energydata_complete.csv')
Energy.head(10)
# Out:
#                   date  Appliances  lights         T1       RH_1     T2  \
# 0  2016-01-11 17:00:00          60      30  19.890000  47.596667  19.20
# 1  2016-01-11 17:10:00          60      30  19.890000  46.693333  19.20
# 2  2016-01-11 17:20:00          50      30  19.890000  46.300000  19.20
# 3  2016-01-11 17:30:00          50      40  19.890000  46.066667  19.20
# 4  2016-01-11 17:40:00          60      40  19.890000  46.333333  19.20
# 5  2016-01-11 17:50:00          50      40  19.890000  46.026667  19.20
# 6  2016-01-11 18:00:00          60      50  19.890000  45.766667  19.20
# 7  2016-01-11 18:10:00          60      50  19.856667  45.560000  19.20
# 8  2016-01-11 18:20:00          60      40  19.790000  45.597500  19.20
# 9  2016-01-11 18:30:00          70      40  19.856667  46.090000  19.23
#
#         RH_2     T3       RH_3         T4  ...         T9   RH_9     T_out  \
# 0  44.790000  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000
# ...

# %%
Energy.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
Energy.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
Energy_new = Energy.drop(columns=['date','lights'])
Energy_new.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
#First we normslise the dataset to a common scale
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_Energy = pd.DataFrame(scaler.fit_transform(Energy_new), columns=Energy_new.columns)
features_Energy = normalised_Energy.drop(columns=['T2'])
heating_target = normalised_Energy['T2']

# %%
features_Energy.head()
# Out:
#    Appliances       T1      RH_1      RH_2        T3      RH_3        T4  \
# 0    0.046729  0.32735  0.566187  0.684038  0.215188  0.746066  0.351351
# 1    0.046729  0.32735  0.541326  0.682140  0.215188  0.748871  0.351351
# 2    0.037383  0.32735  0.530502  0.679445  0.215188  0.755569  0.344745
# 3    0.037383  0.32735  0.524080  0.678414  0.215188  0.758685  0.341441
# 4    0.046729  0.32735  0.531419  0.676727  0.215188  0.758685  0.341441
#
#        RH_4        T5      RH_5  ...        T9      RH_9     T_out  \
# 0  0.764262  0.175506  0.381691  ...  0.223032  0.677290  0.372990
# 1  0.782437  0.175506  0.381691  ...  0.226500  0.678532  0.369239
# 2  0.778062  0.175506  0.380037  ...  0.219563  0.676049  0.365488
# 3  0.770949  0.175506  0.380037  ...  0.219563  0.671909  0.361736
# 4  0.762697  0.178691  0.380037  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
heating_target.head()
# Out:
# 0    0.225345
# 1    0.225345
# 2    0.225345
# 3    0.225345
# 4    0.225345
# Name: T2, dtype: float64

# %%
#Split Data set into training and testing dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features_Energy, heating_target, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
#fit the model to the trianing dataset
linear_model.fit(X_train, y_train)
#obtain predictions
predicted_values = linear_model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 3)
# Out:
# 0.965

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 3)
# Out:
# 0.021

# %%
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 3)
# Out:
# 5.31

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.03

# %%
# Comparing the effects of regularisation
def get_weights_df(linear_model, feat, col_name):
    #this function returns the weights of every feature
    weights = pd.Series(linear_model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha = 0.4, normalize = True)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None, normalize=True,
#       random_state=None, solver='auto', tol=0.001)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.03

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001, normalize= True)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=True, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 4)
# Out:
# 0.0299

# %%
linear_model_weights = get_weights_df(linear_model, X_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, X_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, X_train, 'Lasso_Weight')

# %%
final_weights = pd.merge(linear_model_weights, ridge_weights_df, on = 'Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on= 'Features')

# %%
final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_Weight
# 0          RH_2            -1.020155     -0.378824     -0.000000
# 1         T_out            -0.257216      0.083051      0.000000
# 2            T7            -0.059019      0.017103      0.000000
# 3          RH_8            -0.038711      0.007413      0.000000
# 4        RH_out            -0.037754     -0.079686     -0.000000
# 5            T3            -0.029427      0.063428      0.000000
# 6            T8            -0.026318      0.014768      0.000000
# 7    Appliances            -0.026085      0.035640      0.000000
# 8     Windspeed            -0.018280     -0.006033      0.000000
# 9   Press_mm_hg            -0.000865     -0.003456     -0.000000
# 10          rv2             0.000435      0.000503     -0.000000
# 11          rv1             0.000435      0.000503     -0.000000
# 12   Visibility             0.003560      0.004225     -0.000000
# ...

# %%
# Distribution plot for the dataset
rows = 3
cols = 9

fig, ax = plt.subplots(nrows= rows, ncols= cols, figsize = (16,4))

col = normalised_Energy.columns
index = 0
for i in range(rows):
    for j in range(cols):
        sns.distplot(normalised_Energy[col[index]], ax = ax[i][j])
        index = index + 1

plt.tight_layout()

# %%
# Correlation matrix to select features
corrmat = normalised_Energy.corr()
corrmat
# Out:
#              Appliances        T1      RH_1        T2      RH_2        T3  \
# Appliances     1.000000  0.055447  0.086031  0.120073 -0.060465  0.085060
# T1             0.055447  1.000000  0.164006  0.836834 -0.002509  0.892402
# RH_1           0.086031  0.164006  1.000000  0.269839  0.797535  0.253230
# T2             0.120073  0.836834  0.269839  1.000000 -0.165610  0.735245
# RH_2          -0.060465 -0.002509  0.797535 -0.165610  1.000000  0.137319
# T3             0.085060  0.892402  0.253230  0.735245  0.137319  1.000000
# RH_3           0.036292 -0.028550  0.844677  0.121497  0.678326 -0.011234
# T4             0.040281  0.877001  0.106180  0.762066 -0.047304  0.852778
# RH_4           0.016965  0.097861  0.880359  0.231563  0.721435  0.122737
# T5             0.019760  0.885247  0.205797  0.720550  0.110409  0.888169
# RH_5           0.006955 -0.014782  0.303258  0.029595  0.250271 -0.066355
# T6             0.117638  0.654769  0.316141  0.801186 -0.009670  0.686882
# ...

# %%
# corelation matrix heat map
fig, ax = plt.subplots(figsize = (40,20))
sns.heatmap(corrmat, annot = True, annot_kws={'size':15})

# %%
simple_linear_reg_Energy = Energy[['T2','T6']].sample(15, random_state=2)
sns.regplot(x="T2", y="T6", data=simple_linear_reg_Energy)

# %%
#First we normslise the dataset to a common scale
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_Energy = pd.DataFrame(scaler.fit_transform(Energy_new), columns=Energy_new.columns)
features_Energy = normalised_Energy['T2']
heating_target = normalised_Energy['T6']

# %%
features_Energy
# Out:
# 0        0.225345
# 1        0.225345
# 2        0.225345
# 3        0.225345
# 4        0.225345
#            ...
# 19730    0.711655
# 19731    0.701769
# 19732    0.692651
# 19733    0.677054
# 19734    0.666171
# Name: T2, Length: 19735, dtype: float64

# %%
heating_target
# Out:
# 0        0.381070
# 1        0.375443
# 2        0.367487
# 3        0.363800
# 4        0.361859
#            ...
# 19730    0.898317
# 19731    0.880852
# 19732    0.864260
# 19733    0.829525
# 19734    0.788580
# Name: T6, Length: 19735, dtype: float64
