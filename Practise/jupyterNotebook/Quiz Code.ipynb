# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
A=[1,2,3,4,5,6]
B=[13,21,34]
q= A.extend(B)
print(q)
# Out:
# None

# %%
r=np.identity(3)
print(r)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
fuel_report = pd.read_csv('fuel_ferc1.csv')
print (fuel_report)
fuel_report.shape
fuel_report.info()
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_report.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
fuel_type= fuel_report.groupby('fuel_type_code_pudl').sum().iloc[:,2:]
print(fuel_type)
fuel_type.describe()
# Out:
#                      fuel_qty_burned  fuel_mmbtu_per_unit  \
# fuel_type_code_pudl
# coal                    1.626898e+10        177459.483188
# gas                     5.562880e+10         11737.687844
# nuclear                 4.462058e+09         14382.174064
# oil                     5.089737e+08         46887.135739
# other                   4.923388e+08            95.649646
# waste                   5.168139e+07           150.452780
#
#                      fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# fuel_type_code_pudl
# coal                                576254.381                  9.995814e+05
# gas                                 156891.829                  1.389252e+05
# nuclear                            4053318.428                  2.340864e+07
# oil                                1361824.819                  2.531352e+06
# other                                 3048.394                  2.817538e+03
# ...

# %%
fuel_report.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
fuel_type_coal = fuel_report[(fuel_report['fuel_type_code_pudl']== 'coal')]
fuel_type_coal.describe()
# Out:
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count       8547.000000  8547.000000     8.547000e+03          8547.000000
# mean         115.637534  2004.623143     1.903473e+06            20.762780
# std           72.859332     7.137389     7.206434e+06             3.557467
# min            1.000000  1994.000000     3.000000e+00            10.168000
# 25%           51.000000  1998.000000     4.599130e+05            17.408000
# 50%          122.000000  2004.000000     1.018766e+06            21.250000
# 75%          174.000000  2011.000000     2.104158e+06            24.141000
# max          514.000000  2018.000000     5.558942e+08            28.926390
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count                8547.000000                   8547.000000
# mean                   67.421830                    116.951141
# std                   943.771433                   4043.732781
# ...

# %%
fuel_type_gas = fuel_report[(fuel_report['fuel_type_code_pudl']== 'gas')]
fuel_type_gas.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      11486.000000  11486.000000     1.148600e+04         11486.000000
# mean         124.122062   2005.978060     4.843183e+06             1.021913
# std           73.743929      7.280214     1.180446e+07             0.025270
# min            1.000000   1994.000000     1.000000e+00             0.827100
# 25%           56.000000   1999.250000     5.805600e+04             1.010000
# 50%          134.000000   2006.000000     3.969905e+05             1.022000
# 75%          177.000000   2012.000000     3.198895e+06             1.032488
# max          513.000000   2018.000000     1.663854e+08             1.199200
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               11486.000000                  11486.000000
# mean                   13.659397                     12.095172
# std                   163.286631                    157.032849
# ...

# %%
fuel_type_nuclear = fuel_report[(fuel_report['fuel_type_code_pudl']== 'nuclear')]
fuel_type_nuclear.describe()
# Out:
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count        818.000000   818.000000     8.180000e+02           818.000000
# mean         107.397311  2002.970660     5.454838e+06            17.582120
# std           78.973446     7.155665     1.163650e+07            36.823223
# min            2.000000  1994.000000     1.000000e+00             0.000001
# 25%           39.000000  1997.000000     1.721535e+05             0.000082
# 50%          117.000000  2001.000000     7.603305e+05             0.107995
# 75%          161.000000  2008.000000     1.426256e+06             3.412975
# max          454.000000  2018.000000     5.003856e+07           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count                 818.000000                  8.180000e+02
# mean                 4955.157002                  2.861692e+04
# std                 14291.929749                  4.112873e+05
# ...

# %%
fuel_type_oil = fuel_report[(fuel_report['fuel_type_code_pudl']== 'oil')]
fuel_type_oil.describe()
# Out:
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count       8064.000000  8064.000000     8.064000e+03          8064.000000
# mean         113.236235  2007.195933     6.311677e+04             5.814377
# std           75.998379     6.140652     6.525746e+05             0.205301
# min            1.000000  1994.000000     1.000000e+00             3.103044
# 25%           45.000000  2003.000000     1.150750e+03             5.762064
# 50%          120.000000  2007.000000     4.919000e+03             5.813073
# 75%          170.000000  2012.000000     1.798875e+04             5.880000
# max          514.000000  2018.000000     4.646015e+07             6.812190
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count                8064.000000                   8064.000000
# mean                  168.877086                    313.907691
# std                  2406.101479                   9015.713229
# ...

# %%
fuel_type_other = fuel_report[(fuel_report['fuel_type_code_pudl']== 'other')]
fuel_type_other.describe()
# Out:
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count        167.000000   167.000000     1.670000e+02           167.000000
# mean         110.467066  2001.700599     2.948137e+06             0.572752
# std           47.145735     5.712505     3.227287e+07             6.334943
# min            2.000000  1994.000000     2.500000e+01             0.000048
# 25%           89.000000  1997.000000     2.802500e+03             0.007187
# 50%           99.000000  2000.000000     1.104600e+04             0.013950
# 75%          132.000000  2006.000000     5.869520e+05             0.138457
# max          281.000000  2016.000000     4.172977e+08            81.910118
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count                 167.000000                    167.000000
# mean                   18.253856                     16.871485
# std                    29.016882                     27.659197
# ...

# %%
fuel_type_waste = fuel_report[(fuel_report['fuel_type_code_pudl']== 'waste')]
fuel_type_waste.describe()
# Out:
#        utility_id_ferc1  report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count        441.000000   441.000000       441.000000           441.000000
# mean         154.253968  2005.650794    117191.362812             0.341163
# std           53.367073     7.460231    177792.638360             1.646289
# min            9.000000  1994.000000         7.000000             0.000009
# 25%          121.000000  1998.000000      3136.000000             0.005508
# 50%          182.000000  2006.000000     15636.000000             0.012315
# 75%          194.000000  2012.000000    186916.000000             0.015055
# max          432.000000  2018.000000    799499.000000             8.700000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count                 441.000000                    441.000000
# mean                   19.518122                     18.413052
# std                    29.988017                     27.966921
# ...

# %%
fuel_qty_burned = fuel_report['fuel_qty_burned']
fuel_qty_burned.describe()
# Out:
# count    2.952300e+04
# mean     2.622119e+06
# std      9.118004e+06
# min      1.000000e+00
# 25%      1.381700e+04
# 50%      2.533220e+05
# 75%      1.424034e+06
# max      5.558942e+08
# Name: fuel_qty_burned, dtype: float64

# %%
fuel_qty_burned.skew()
# Out:
# 15.851495469109503

# %%
fuel_qty_burned.kurtosis()
# Out:
# 651.3694501337732

# %%
fuel_report.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
fuel_year = fuel_report['report_year']
fuel_year.describe()
# Out:
# count    29523.000000
# mean      2005.806050
# std          7.025483
# min       1994.000000
# 25%       2000.000000
# 50%       2006.000000
# 75%       2012.000000
# max       2018.000000
# Name: report_year, dtype: float64

# %%
coal= fuel_report.groupby(['report_year', 'fuel_type_code_pudl']).sum()
coal
# Out:
#                                  utility_id_ferc1  fuel_qty_burned  \
# report_year fuel_type_code_pudl
# 1994        coal                            50430     7.172082e+08
#             gas                             54449     2.432212e+09
#             nuclear                          6643     2.069366e+08
#             oil                             14821     1.469716e+06
#             other                            1208     5.094458e+06
# ...                                           ...              ...
# 2018        coal                            28278     3.216100e+08
#             gas                             60737     3.476148e+09
#             nuclear                          2602     1.670945e+08
#             oil                             33226     5.975283e+06
#             waste                            2277     3.296373e+06
#
#                                  fuel_mmbtu_per_unit  \
# report_year fuel_type_code_pudl
# ...

# %%
coal.describe(include='all')
# Out:
#        utility_id_ferc1  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count        148.000000     1.480000e+02           148.000000
# mean       23658.662162     5.230597e+08          1694.003941
# std        23056.195794     8.455670e+08          2640.566904
# min           98.000000     5.436080e+05             0.001410
# 25%         2232.750000     3.005318e+06             8.683033
# 50%         7023.500000     1.496010e+08           455.871815
# 75%        45321.000000     6.067675e+08          2189.399671
# max        64800.000000     3.476148e+09         10293.429297
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count                 148.000000                  1.480000e+02
# mean                41621.252318                  1.830367e+05
# std                 70835.914915                  1.287576e+06
# min                  -489.141000                 -4.257170e+02
# 25%                   445.812750                  4.130270e+02
# ...
